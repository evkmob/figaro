# %% [markdown]
# <a href="https://colab.research.google.com/github/evkmob/figaro/blob/master/%D0%9A%D0%BE%D1%80%D0%BE%D1%82%D0%BA%D0%BE%D0%B2%D0%B0_%D0%95_%D0%92_%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_%E2%84%9612.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# 1. Кортеж (*но такое оформление без круглых скобок не рекомендуется по PEP8*)
# 2. Строка
# 3. Кортеж
# 4. Строка
# 5. Строка
# 6. Список
# 7. Целое число

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %%
text = input('Введите фразу: ')
print ()
